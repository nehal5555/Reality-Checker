# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
from wordcloud import WordCloud

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Conv1D, MaxPool1D
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %%
fake = pd.read_csv('Fake.csv')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
fake.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
fake['subject'].value_counts()
# Out:
# subject
# News               9050
# politics           6841
# left-news          4459
# Government News    1570
# US_News             783
# Middle-east         778
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = 'subject', data=fake)
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %%
## WordCloud

# %%
text = ' '.join(fake['text'].tolist())

# %%
wordcloud = WordCloud(width=1920, height=1000).generate(text)
fig = plt.figure(figsize=(10, 10))
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
real = pd.read_csv('True.csv')

# %%
text = ' '.join(real['text'].tolist())

# %%
wordcloud = WordCloud(width=1920, height=1000).generate(text)
fig = plt.figure(figsize=(10, 10))
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
real.sample(5)
# Out:
#                                                    title  \
# 19411  Exclusive: Turkey to deploy troops inside Syri...
# 13668  China police say some claims of abuse at Beiji...
# 12465  Albania plans ambitious road revamp, energy ma...
# 11198  Cruz, Rubio say Iran prisoner swap a 'dangerou...
# 12544  Merkel, Social Democrats seek clarity on coali...
#
#                                                     text       subject  \
# 19411  NEW YORK (Reuters) - Turkish President Tayyip ...     worldnews
# 13668  SHANGHAI (Reuters) - Chinese police said late ...     worldnews
# 12465  TIRANA (Reuters) - Albania will upgrade its ro...     worldnews
# 11198  WASHINGTON (Reuters) - Republican presidential...  politicsNews
# 12544  BERLIN (Reuters) - German Chancellor Angela Me...     worldnews
#
#                       date
# 19411  September 21, 2017
# 13668   November 28, 2017
# 12465   December 12, 2017
# 11198    January 17, 2016
# 12544   December 11, 2017

# %%
unknown_publishers = []
for index, row in enumerate(real.text.values):
    try:
        record = row.split(' - ', maxsplit=1)
        record[1]

        assert(len(record[0])<260)
    except:
        unknown_publishers.append(index)

# %%
len(unknown_publishers)
# Out:
# 35

# %%
real.iloc[unknown_publishers].text
# Out:
# 2922     The following statements were posted to the ve...
# 3488     The White House on Wednesday disclosed a group...
# 3782     The following statements were posted to the ve...
# 4358     Neil Gorsuch, President Donald Trump’s appoint...
# 4465     WASHINGTON The clock began running out this we...
# 5290     The following statements were posted to the ve...
# 5379     The following statements were posted to the ve...
# 5412     The following statements were posted to the ve...
# 5504     The following statements were posted to the ve...
# 5538     The following statements were posted to the ve...
# 5588     The following statements were posted to the ve...
# 5593     The following statements were posted to the ve...
# 5761     The following bullet points are from the U.S. ...
# 5784     Federal appeals court judge Neil Gorsuch, the ...
# 6026     The following bullet points are from the U.S. ...
# 6184     The following bullet points are from the U.S. ...
# 6660     Republican members of Congress are complaining...
# 6823     Over the course of the U.S. presidential campa...
# 7922     After going through a week reminiscent of Napo...
# 8194     The following timeline charts the origin and s...
# 8195     Global health officials are racing to better u...
# 8247     U.S. President Barack Obama visited a street m...
# 8465     ALGONAC, MICH.—Parker Fox drifted out of the D...
# 8481     Global health officials are racing to better u...
# 8482     The following timeline charts the origin and s...
# 8505     Global health officials are racing to better u...
# 8506     The following timeline charts the origin and s...
# 8771     In a speech weighted with America’s complicate...
# 8970
# 9008     The following timeline charts the origin and s...
# 9009     Global health officials are racing to better u...
# 9307     It’s the near future, and North Korea’s regime...
# 9618     GOP leaders have unleashed a stunning level of...
# 9737     Caitlyn Jenner posted a video on Wednesday (Ap...
# 10479    The Democratic and Republican nominees for the...
# Name: text, dtype: object

# %%
real.iloc[8970]
# Out:
# title      Graphic: Supreme Court roundup
# text
# subject                      politicsNews
# date                       June 16, 2016
# Name: 8970, dtype: object

# %%
real = real.drop(8970, axis=0)

# %%
publisher = []
tmp_text = []

for index, row in enumerate(real.text.values):
    if index in unknown_publishers:
        tmp_text.append(row)
        publisher.append('Unknown')
    else:
        record = row.split('-',maxsplit=1)
        publisher.append(record[0].strip())
        tmp_text.append(record[1].strip())

# %%
real['publisher']=publisher
real['text']=tmp_text

# %%
real.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  The head of a conservative Republican faction ...  politicsNews
# 1  Transgender people will be allowed for the fir...  politicsNews
# 2  The special counsel investigation of links bet...  politicsNews
# 3  Trump campaign adviser George Papadopoulos tol...  politicsNews
# 4  President Donald Trump called on the U.S. Post...  politicsNews
#
#                  date                     publisher
# 0  December 31, 2017           WASHINGTON (Reuters)
# 1  December 29, 2017           WASHINGTON (Reuters)
# 2  December 31, 2017           WASHINGTON (Reuters)
# 3  December 30, 2017           WASHINGTON (Reuters)
# 4  December 29, 2017   SEATTLE/WASHINGTON (Reuters)

# %%
real.shape
# Out:
# (21416, 5)

# %%
empty_fake_index = [index for index, text in enumerate(fake.text.tolist()) if str(text).strip()==""]

# %%
fake.iloc[empty_fake_index]
# Out:
#                                                    title text    subject  \
# 10923  TAKE OUR POLL: Who Do You Think President Trum...        politics
# 11041  Joe Scarborough BERATES Mika Brzezinski Over “...        politics
# 11190  WATCH TUCKER CARLSON Scorch Sanctuary City May...        politics
# 11225  MAYOR OF SANCTUARY CITY: Trump Trying To Make ...        politics
# 11236  SHOCKER: Public School Turns Computer Lab Into...        politics
# ...                                                  ...  ...        ...
# 21816  BALTIMORE BURNS: MARYLAND GOVERNOR BRINGS IN N...       left-news
# 21826  FULL VIDEO: THE BLOCKBUSTER INVESTIGATION INTO...       left-news
# 21827  (VIDEO) HILLARY CLINTON: RELIGIOUS BELIEFS MUS...       left-news
# 21857  (VIDEO)ICE PROTECTING OBAMA: WON’T RELEASE NAM...       left-news
# 21873  (VIDEO) HYSTERICAL SNL TAKE ON HILLARY’S ANNOU...       left-news
#
#                date
# 10923  May 10, 2017
# 11041  Apr 26, 2017
# 11190   Apr 6, 2017
# 11225   Apr 2, 2017
# 11236   Apr 1, 2017
# ...             ...
# 21816  Apr 27, 2015
# 21826  Apr 25, 2015
# 21827  Apr 25, 2015
# 21857  Apr 14, 2015
# 21873  Apr 12, 2015
#
# [630 rows x 4 columns]

# %%
real['text'] = real['title'] + " " + real['text']
fake['text'] = fake['title'] + " " + fake['text']

# %%
real['text'] = real['text'].apply(lambda x: str(x).lower())
fake['text'] = fake['text'].apply(lambda x: str(x).lower())

# %%
real['class'] = 1
fake['class'] = 0

# %%
real.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'publisher', 'class'], dtype='object')

# %%
real = real[['text', 'class']]

# %%
fake = fake[['text', 'class']]

# %%
data = real._append(fake, ignore_index=True)

# %%
# !pip install spacy==2.2.3
# !python -m spacy download en_core_web_sm
# !pip install beautifulsoap4==4.9.1
# !pip install textblob==0.15.3
# !pip install git+https://github.com/laxmimerit/preprocess_kgptalkie.git --upgrade --force-reinstall
# Out:
# Collecting spacy==2.2.3
#   Downloading spacy-2.2.3.tar.gz (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 706.2 kB/s eta 0:00:00 kB/s eta 0:00:01:01
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "/Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/gl/h9xtrwdn7kd4fh9qh1xykrk80000gn/T/pip-build-env-vql9av6y/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 334, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/gl/h9xtrwdn7kd4fh9qh1xykrk80000gn/T/pip-build-env-vql9av6y/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 304, in _get_build_requires
#           self.run_setup()
#         File "/private/var/folders/gl/h9xtrwdn7kd4fh9qh1xykrk80000gn/T/pip-build-env-vql9av6y/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 320, in run_setup
#           exec(code, locals())
#         File "<string>", line 11, in <module>
#       ImportError: cannot import name 'msvccompiler' from 'distutils' (/private/var/folders/gl/h9xtrwdn7kd4fh9qh1xykrk80000gn/T/pip-build-env-vql9av6y/overlay/lib/python3.12/site-packages/setuptools/_distutils/__init__.py). Did you mean: 'ccompiler'?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 1.8 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from en-core-web-sm==3.7.1) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: numpy>=1.19.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.10.6)
# Requirement already satisfied: jinja2 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.5)
# Requirement already satisfied: setuptools in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ERROR: Could not find a version that satisfies the requirement beautifulsoap4==4.9.1 (from versions: none)
# ERROR: No matching distribution found for beautifulsoap4==4.9.1
# Requirement already satisfied: textblob==0.15.3 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from textblob==0.15.3) (3.9.1)
# Requirement already satisfied: click in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from nltk>=3.1->textblob==0.15.3) (8.1.8)
# Requirement already satisfied: joblib in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from nltk>=3.1->textblob==0.15.3) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from nltk>=3.1->textblob==0.15.3) (2024.11.6)
# Requirement already satisfied: tqdm in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from nltk>=3.1->textblob==0.15.3) (4.66.4)
# Collecting git+https://github.com/laxmimerit/preprocess_kgptalkie.git
#   Cloning https://github.com/laxmimerit/preprocess_kgptalkie.git to /private/var/folders/gl/h9xtrwdn7kd4fh9qh1xykrk80000gn/T/pip-req-build-b3hld9xg
#   Running command git clone --filter=blob:none --quiet https://github.com/laxmimerit/preprocess_kgptalkie.git /private/var/folders/gl/h9xtrwdn7kd4fh9qh1xykrk80000gn/T/pip-req-build-b3hld9xg
#   Resolved https://github.com/laxmimerit/preprocess_kgptalkie.git to commit 0f56a6502679f6750b7f0ffed98f590d1f0246bd
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: preprocess_kgptalkie
#   Building wheel for preprocess_kgptalkie (setup.py) ... done
#   Created wheel for preprocess_kgptalkie: filename=preprocess_kgptalkie-0.11-py3-none-any.whl size=8175 sha256=83f42caf52fe232144733b444fe34b78326e517e81ca1487906731f5461bb4a1
#   Stored in directory: /private/var/folders/gl/h9xtrwdn7kd4fh9qh1xykrk80000gn/T/pip-ephem-wheel-cache-4e4fy1ov/wheels/24/f6/5f/6a2a2252acab6c8ce06a71a210d40e9b744871a9132dbf59bc
# Successfully built preprocess_kgptalkie
# Installing collected packages: preprocess_kgptalkie
#   Attempting uninstall: preprocess_kgptalkie
#     Found existing installation: preprocess_kgptalkie 0.11
#     Uninstalling preprocess_kgptalkie-0.11:
#       Successfully uninstalled preprocess_kgptalkie-0.11
# Successfully installed preprocess_kgptalkie-0.11

# %%
import preprocess_kgptalkie as ps

# %%
data['text'] = data['text'].apply(lambda x: ps.remove_special_chars(x))

# %%
ps.remove_special_chars('this ,. @ # is great')
# Out:
# 'this    is great'

# %%
data.head()
# Out:
#                                                 text  class
# 0  as us budget fight looms republicans flip thei...      1
# 1  us military to accept transgender recruits on ...      1
# 2  senior us republican senator let mr mueller do...      1
# 3  fbi russia probe helped by australian diplomat...      1
# 4  trump wants postal service to charge much more...      1

# %%
# Word2Vec

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from gensim) (1.26.4)
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.3.3-cp312-cp312-macosx_11_0_arm64.whl (24.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:01:020m
# Downloading scipy-1.13.1-cp312-cp312-macosx_12_0_arm64.whl (30.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.4/30.4 MB 1.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: scipy, gensim
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.1
#     Uninstalling scipy-1.15.1:
#       Successfully uninstalled scipy-1.15.1
# Successfully installed gensim-4.3.3 scipy-1.13.1

# %%
# !pip install gensim==3.8.3
import gensim
# Out:
# Collecting gensim==3.8.3
#   Downloading gensim-3.8.3.tar.gz (23.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 749.7 kB/s eta 0:00:00m eta 0:00:010:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.11.3 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from gensim==3.8.3) (1.26.4)
# Requirement already satisfied: scipy>=0.18.1 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from gensim==3.8.3) (1.13.1)
# Requirement already satisfied: six>=1.5.0 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from gensim==3.8.3) (1.17.0)
# Requirement already satisfied: smart_open>=1.8.1 in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from gensim==3.8.3) (7.1.0)
# Requirement already satisfied: wrapt in /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages (from smart_open>=1.8.1->gensim==3.8.3) (1.17.2)
# Building wheels for collected packages: gensim
#   Building wheel for gensim (setup.py) ... rror
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [681 lines of output]
#       /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages/setuptools/__init__.py:85: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages/setuptools/_distutils/dist.py:268: UserWarning: Unknown distribution option: 'test_suite'
#         warnings.warn(msg)
#       /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages/setuptools/_distutils/dist.py:268: UserWarning: Unknown distribution option: 'tests_require'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.1-arm64-cpython-312
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/interfaces.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/downloader.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/matutils.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/utils.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/nosy.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       copying gensim/similarities/index.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       copying gensim/similarities/docsim.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       copying gensim/similarities/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       copying gensim/similarities/nmslib.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       copying gensim/similarities/levenshtein.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       copying gensim/similarities/termsim.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_text_analysis.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_glove2word2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_parsing.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_tmdiff.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_matutils.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_keywords.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_word2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_segmentation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_lsimodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_coherencemodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_miislita.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_wordrank_wrapper.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_phrases.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_BM25.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_sklearn_api.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_dtm.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_tfidfmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_poincare.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_rpmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_corpora_hashdictionary.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/simspeed2.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_aggregation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_varembed_wrapper.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_lee.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_big.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_translation_matrix.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/basetmtests.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_ldaseqmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_datatype.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_summarization.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_ldavowpalwabbit_wrapper.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_similarity_metrics.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_ldamodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_nmf.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_lda_callback.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/utils.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_keyedvectors.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_ldamallet_wrapper.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_fasttext_wrapper.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_corpora_dictionary.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_d2vmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/svd_error.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_logentropy_model.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_doc2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_similarities.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_keras_integration.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_direct_confirmation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_api.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_atmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_corpora.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_indirect_confirmation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_probability_estimation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_fasttext.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_utils_any2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_scripts.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_normmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_hdpmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_sharded_corpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/simspeed.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/summarization
#       copying gensim/summarization/bm25.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/summarization
#       copying gensim/summarization/textcleaner.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/summarization
#       copying gensim/summarization/graph.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/summarization
#       copying gensim/summarization/keywords.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/summarization
#       copying gensim/summarization/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/summarization
#       copying gensim/summarization/commons.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/summarization
#       copying gensim/summarization/summarizer.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/summarization
#       copying gensim/summarization/pagerank_weighted.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/summarization
#       copying gensim/summarization/mz_entropy.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/summarization
#       copying gensim/summarization/syntactic_unit.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/summarization
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/poincare.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/basemodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/phrases.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/_fasttext_bin.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/word2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/normmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/translation_matrix.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/lsimodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/rpmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/logentropy_model.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/keyedvectors.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/lda_worker.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/fasttext.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/tfidfmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/doc2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/callbacks.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/hdpmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/ldamulticore.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/ldaseqmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/lsi_dispatcher.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/lda_dispatcher.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/utils_any2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/base_any2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/ldamodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/nmf.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/atmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/lsi_worker.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/coherencemodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/hdp.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/phrases.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/lsimodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/rpmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/ftmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/ldaseqmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/text2bow.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/ldamodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/w2vmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/tfidf.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/atmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       copying gensim/sklearn_api/d2vmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/sklearn_api
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/viz
#       copying gensim/viz/poincare.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/viz
#       copying gensim/viz/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/viz
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/make_wikicorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/word2vec2tensor.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/package_info.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/make_wiki_online_lemma.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/segment_wiki.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/make_wiki_online.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/make_wiki.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/make_wiki_lemma.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/make_wiki_online_nodebug.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/glove2word2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/word2vec_standalone.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/parsing
#       copying gensim/parsing/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/parsing
#       copying gensim/parsing/preprocessing.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/parsing
#       copying gensim/parsing/porter.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/parsing
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/direct_confirmation_measure.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/aggregation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/text_analysis.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/probability_estimation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/indirect_confirmation_measure.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/segmentation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/sharded_corpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/textcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/wikicorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/csvcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/malletcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/mmcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/ucicorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/indexedcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/lowcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/bleicorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/dictionary.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/svmlightcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/hashdictionary.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/models/wrappers
#       copying gensim/models/wrappers/dtmmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/wrappers
#       copying gensim/models/wrappers/ldavowpalwabbit.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/wrappers
#       copying gensim/models/wrappers/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/wrappers
#       copying gensim/models/wrappers/varembed.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/wrappers
#       copying gensim/models/wrappers/fasttext.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/wrappers
#       copying gensim/models/wrappers/ldamallet.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/wrappers
#       copying gensim/models/wrappers/wordrank.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/wrappers
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/models/deprecated
#       copying gensim/models/deprecated/old_saveload.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/deprecated
#       copying gensim/models/deprecated/word2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/deprecated
#       copying gensim/models/deprecated/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/deprecated
#       copying gensim/models/deprecated/fasttext_wrapper.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/deprecated
#       copying gensim/models/deprecated/keyedvectors.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/deprecated
#       copying gensim/models/deprecated/fasttext.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/deprecated
#       copying gensim/models/deprecated/doc2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models/deprecated
#       running egg_info
#       writing gensim.egg-info/PKG-INFO
#       writing dependency_links to gensim.egg-info/dependency_links.txt
#       writing requirements to gensim.egg-info/requires.txt
#       writing top-level names to gensim.egg-info/top_level.txt
#       reading manifest file 'gensim.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching 'COPYING.LESSER'
#       warning: no files found matching 'ez_setup.py'
#       warning: no files found matching 'gensim/models/doc2vec_inner.c'
#       adding license file 'COPYING'
#       writing manifest file 'gensim.egg-info/SOURCES.txt'
#       /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages/setuptools/command/build_py.py:215: _Warning: Package 'gensim.test.test_data' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages/setuptools/command/build_py.py:215: _Warning: Package 'gensim.test.test_data.DTM' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.DTM' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.DTM' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.DTM' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.DTM' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages/setuptools/command/build_py.py:215: _Warning: Package 'gensim.test.test_data.PathLineSentences' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.PathLineSentences' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.PathLineSentences' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.PathLineSentences' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.PathLineSentences' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages/setuptools/command/build_py.py:215: _Warning: Package 'gensim.test.test_data.old_d2v_models' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.old_d2v_models' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.old_d2v_models' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.old_d2v_models' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.old_d2v_models' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages/setuptools/command/build_py.py:215: _Warning: Package 'gensim.test.test_data.old_w2v_models' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.old_w2v_models' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.old_w2v_models' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.old_w2v_models' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.old_w2v_models' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       copying gensim/_matutils.c -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/_matutils.pyx -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/EN.1-10.cbow1_wind5_hs0_neg10_size300_smpl1e-05.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/IT.1-10.cbow1_wind5_hs0_neg10_size300_smpl1e-05.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/OPUS_en_it_europarl_train_one2ten.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/alldata-id-10.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/atmodel_3_0_1_model -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/atmodel_3_0_1_model.expElogbeta.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/atmodel_3_0_1_model.id2word -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/atmodel_3_0_1_model.state -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/bgwiki-latest-pages-articles-shortened.xml.bz2 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/compatible-hash-false.model -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/compatible-hash-true.model -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/cp852_fasttext.bin -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/crime-and-punishment.bin -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/crime-and-punishment.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/crime-and-punishment.vec -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/d2v-lee-v0.13.0 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/doc2vec_old -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/doc2vec_old_sep -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/doc2vec_old_sep.syn0_lockf.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/doc2vec_old_sep.syn1neg.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/dtm_test.dict -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/dtm_test.mm -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/enwiki-latest-pages-articles1.xml-p000000010p000030302-shortened.bz2 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/enwiki-table-markup.xml.bz2 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/euclidean_vectors.bin -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/fasttext_old -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/fasttext_old_sep -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/fasttext_old_sep.syn0_lockf.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/fasttext_old_sep.syn1neg.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/fb-ngrams.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/ft_kv_3.6.0.model.gz -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/ft_model_2.3.0 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/head500.noblanks.cor -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/head500.noblanks.cor.bz2 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/head500.noblanks.cor_tfidf.model -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/head500.noblanks.cor_wordids.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/high_precision.kv.bin -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/high_precision.kv.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/large_tag_doc_10_iter50 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/lda_3_0_1_model -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/lda_3_0_1_model.expElogbeta.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/lda_3_0_1_model.id2word -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/lda_3_0_1_model.state -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_2_7 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_2_7.expElogbeta.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_2_7.id2word -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_2_7.state -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_3_5 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_3_5.expElogbeta.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_3_5.id2word -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_3_5.state -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/ldavowpalwabbit.dict.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/ldavowpalwabbit.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/lee.cor -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/lee_background.cor -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/lee_fasttext -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/lee_fasttext.bin -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/lee_fasttext.vec -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/lee_fasttext_new.bin -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/miIslita.cor -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/mihalcea_tarau.kw.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/mihalcea_tarau.kwpos.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/mihalcea_tarau.summ.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/mihalcea_tarau.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/mini_newsgroup -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/nmf_model -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/non_ascii_fasttext.bin -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/old_keyedvectors_320.dat -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/pang_lee_polarity.cor -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/pang_lee_polarity_fasttext.bin -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/pang_lee_polarity_fasttext.vec -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/para2para_text1.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/para2para_text2.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/phraser-3.6.0.model -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/phraser-no-common-terms.pkl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/phraser-no-scoring.pkl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/phraser-scoring-str.pkl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/phrases-3.6.0.model -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/phrases-no-common-terms.pkl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/phrases-no-scoring.pkl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/phrases-scoring-str.pkl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/phrases-transformer-new-v3-5-0.pkl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/phrases-transformer-v3-5-0.pkl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/poincare_cp852.tsv -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/poincare_hypernyms.tsv -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/poincare_hypernyms_large.tsv -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/poincare_test_3.4.0 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/poincare_utf8.tsv -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/poincare_vectors.bin -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/pre_0_13_2_model -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/pre_0_13_2_model.state -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/pretrained.vec -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/questions-words.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/reproduce.dat -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/reproduce.dat.gz -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/similarities0-1.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/simlex999.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/small_tag_doc_5_iter50 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/test_corpus_ok.mm -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/test_corpus_small.mm -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/test_glove.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_corrupt.mm -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_no_index.mm -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_no_index.mm.bz2 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_no_index.mm.gz -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_overflow.mm -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_with_index.mm -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
# ...
#       copying gensim/test/test_data/testsummarization_unrelated.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/tfidf_model.tst -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/tfidf_model.tst.bz2 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/tfidf_model_3_2.tst -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/toy-data.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/toy-model-pretrained.bin -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/toy-model.bin -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/toy-model.vec -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/varembed_lee_subcorpus.cor -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/varembed_morfessor.bin -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/varembed_vectors.pkl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/w2v-lee-v0.12.0 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/w2v_keyedvectors_load_test.modeldata -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/w2v_keyedvectors_load_test.vocab -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_3.3 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep.syn0_lockf.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep.syn1neg.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_c -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py2 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py3 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py3_4 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.neg_labels.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn0.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn0_lockf.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn1neg.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.neg_labels.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn0.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn0_lockf.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn1neg.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.neg_labels.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn0.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn0_lockf.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn1neg.npy -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       copying gensim/test/test_data/wordsim353.tsv -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/DTM
#       copying gensim/test/test_data/DTM/ldaseq_3_0_1_model -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/DTM
#       copying gensim/test/test_data/DTM/sstats_test.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/DTM
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/PathLineSentences
#       copying gensim/test/test_data/PathLineSentences/1.txt -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/PathLineSentences
#       copying gensim/test/test_data/PathLineSentences/2.txt.bz2 -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/PathLineSentences
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.1.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.2.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.3.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.4.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.1.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.2.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.3.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.4.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_1.0.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_1.0.1.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_2.0.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_2.1.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_2.2.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_2.3.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.0.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.1.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.2.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.3.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.4.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_d2v_models
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.1.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.2.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.3.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.4.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.1.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.2.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.3.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.4.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_1.0.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_1.0.1.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_2.0.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_2.1.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_2.2.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_2.3.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.0.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.1.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.2.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.3.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.4.0.mdl -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test/test_data/old_w2v_models
#       copying gensim/models/_utils_any2vec.c -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/_utils_any2vec.pyx -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/doc2vec_corpusfile.cpp -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/doc2vec_corpusfile.pyx -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/doc2vec_inner.cpp -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/doc2vec_inner.pxd -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/doc2vec_inner.pyx -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/fast_line_sentence.h -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/fasttext_corpusfile.cpp -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/fasttext_corpusfile.pyx -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/fasttext_inner.c -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/fasttext_inner.pxd -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/fasttext_inner.pyx -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/nmf_pgd.c -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/nmf_pgd.pyx -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/stdint_wrapper.h -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/voidptr.h -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/word2vec_corpusfile.cpp -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/word2vec_corpusfile.pxd -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/word2vec_corpusfile.pyx -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/word2vec_inner.c -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/word2vec_inner.pxd -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/word2vec_inner.pyx -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/corpora/_mmreader.c -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/_mmreader.pyx -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       running build_ext
#       building 'gensim.models.word2vec_inner' extension
#       creating build/temp.macosx-11.1-arm64-cpython-312
#       creating build/temp.macosx-11.1-arm64-cpython-312/gensim
#       creating build/temp.macosx-11.1-arm64-cpython-312/gensim/models
#       clang -fno-strict-overflow -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /Users/arnavraj/programming-with-qiskit/miniconda3/include -arch arm64 -fPIC -O2 -isystem /Users/arnavraj/programming-with-qiskit/miniconda3/include -arch arm64 -I/Users/arnavraj/programming-with-qiskit/miniconda3/include/python3.12 -I/Users/arnavraj/programming-with-qiskit/miniconda3/lib/python3.12/site-packages/numpy/core/include -c gensim/models/word2vec_inner.c -o build/temp.macosx-11.1-arm64-cpython-312/gensim/models/word2vec_inner.o
#       gensim/models/word2vec_inner.c:216:12: fatal error: 'longintrepr.h' file not found
#         216 |   #include "longintrepr.h"
#             |            ^~~~~~~~~~~~~~~
#       1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for gensim
#   Running setup.py clean for gensim
# Failed to build gensim
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (gensim)

# %%
y = data['class'].values

# %%
X = [d.split() for d in data['text'].tolist()]

# %%
DIM = 100
w2v_model = gensim.models.Word2Vec(sentences=X, window=10, min_count=1, vector_size=DIM)

# %%
len(w2v_model.wv)
# Out:
# 230832

# %%
w2v_model.wv.most_similar('love')
# Out:
# [('applaud', 0.7773945331573486),
#  ('thank', 0.7061914801597595),
#  ('appreciate', 0.6753990650177002),
#  ('admire', 0.6585491895675659),
#  ('wish', 0.6521860361099243),
#  ('beautiful', 0.6382116675376892),
#  ('bless', 0.6372109651565552),
#  ('wonderful', 0.6261763572692871),
#  ('forgive', 0.6056752800941467),
#  ('loves', 0.5920453667640686)]

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)

# %%
X = tokenizer.texts_to_sequences(X)

# %%
# tokenizer.word_index

# %%
plt.hist([len(x) for x in X], bins = 700)
plt.show()

# %%
nos = np.array([len(x) for x in X])
len(nos[nos>1000])
# Out:
# 1582

# %%
maxlen = 1000
X = pad_sequences(X, maxlen=maxlen)

# %%
len(X[101])
# Out:
# 1000

# %%
vocab_size = len(tokenizer.word_index) + 1
vocab = tokenizer.word_index

# %%
def get_weight_matrix(model):
    weight_matrix = np.zeros((vocab_size, DIM))

    for word, i in vocab.items():
        weight_matrix[i] = model.wv[word]

    return weight_matrix

# %%
embedding_vectors = get_weight_matrix(w2v_model)

# %%
embedding_vectors.shape
# Out:
# (230833, 100)

# %%
model = Sequential()
model.add(Embedding(vocab_size, output_dim=DIM, weights = [embedding_vectors], trainable = True))
model.add(LSTM(units=128))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │    23,083,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,083,300 (88.06 MB)
#  Trainable params: 23,083,300 (88.06 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model.fit(X_train, y_train, validation_split=0.3, epochs=6)
# Out:
# Epoch 1/6
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 437s 591ms/step - acc: 0.9177 - loss: 0.2028 - val_acc: 0.9783 - val_loss: 0.0661
# Epoch 2/6
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 433s 587ms/step - acc: 0.9853 - loss: 0.0475 - val_acc: 0.9756 - val_loss: 0.0714
# Epoch 3/6
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 453s 614ms/step - acc: 0.9925 - loss: 0.0237 - val_acc: 0.9889 - val_loss: 0.0340
# Epoch 4/6
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 426s 578ms/step - acc: 0.9979 - loss: 0.0083 - val_acc: 0.9869 - val_loss: 0.0395
# Epoch 5/6
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 405s 550ms/step - acc: 0.9987 - loss: 0.0039 - val_acc: 0.9911 - val_loss: 0.0316
# Epoch 6/6
# 737/737 ━━━━━━━━━━━━━━━━━━━━ 412s 559ms/step - acc: 0.9997 - loss: 0.0013 - val_acc: 0.9934 - val_loss: 0.0240

# %%
y_pred = (model.predict(X_test) >= 0.5).astype(int)
# Out:
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 52s 149ms/step

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9940311804008909

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5881
#            1       0.99      0.99      0.99      5344
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
x = ['this is a news']
x = tokenizer.texts_to_sequences(x)
x = pad_sequences(x, maxlen=maxlen)

# %%
(model.predict(x) >= 0.5).astype(int)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# array([[0]])

# %%
x = ['HMPV: Virus cases on the rise in UK as doctors issue ‘mask up’ warning']
x = tokenizer.texts_to_sequences(x)
x = pad_sequences(x, maxlen=maxlen)

# %%
(model.predict(x) >= 0.5).astype(int)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# array([[1]])
